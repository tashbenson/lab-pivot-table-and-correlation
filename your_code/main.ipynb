# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
employee = pd.read_csv("data/Employee.csv")
employee.head(20)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
# Method 1 - Groupby
employee.groupby(['Department']).agg({'Salary':np.mean})
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %%
# Method 2 - Pivot table 
employee.pivot_table(index=['Department'],values = ['Salary'], aggfunc=['mean'])
# Out:
#              mean
#            Salary
# Department
# HR          45.00
# IT          48.75
# Sales       55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
employee.pivot_table(index=['Department', 'Title'],values = ['Salary'], aggfunc=['mean'])
# Out:
#                        mean
#                      Salary
# Department Title
# HR         VP          70.0
#            analyst     32.5
# IT         VP          70.0
#            analyst     32.5
#            associate   60.0
# Sales      associate   55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
employee.pivot_table(index=['Department', 'Title'],values = ['Salary','Years'], aggfunc=['mean'])
# Out:
#                        mean
#                      Salary Years
# Department Title
# HR         VP          70.0   8.0
#            analyst     32.5   3.0
# IT         VP          70.0   8.0
#            analyst     32.5   1.5
#            associate   60.0   7.0
# Sales      associate   55.0   2.5

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
employee.groupby(['Department','Title']).agg({'Name':'count','Salary':np.mean})
# Out:
#                       Name  Salary
# Department Title
# HR         VP            1    70.0
#            analyst       2    32.5
# IT         VP            1    70.0
#            analyst       2    32.5
#            associate     1    60.0
# Sales      associate     2    55.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
employee_pivot = employee.pivot_table(index=['Department', 'Title'],values = ['Salary'], aggfunc=['median','min','max',np.std,'count'])
employee_pivot
# Out:
#                      median    min    max       std  count
#                      Salary Salary Salary    Salary Salary
# Department Title
# HR         VP          70.0     70     70       NaN      1
#            analyst     32.5     30     35  3.535534      2
# IT         VP          70.0     70     70       NaN      1
#            analyst     32.5     30     35  3.535534      2
#            associate   60.0     60     60       NaN      1
# Sales      associate   55.0     55     55  0.000000      2

# %%
# Where std is nan - there is only one employee
# For the sales associate the std is 0 as the emloyees have the same salary

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
employee_pivot = employee_pivot.fillna(0)
employee_pivot
# Out:
#                      median    min    max       std  count
#                      Salary Salary Salary    Salary Salary
# Department Title
# HR         VP          70.0     70     70  0.000000      1
#            analyst     32.5     30     35  3.535534      2
# IT         VP          70.0     70     70  0.000000      1
#            analyst     32.5     30     35  3.535534      2
#            associate   60.0     60     60  0.000000      1
# Sales      associate   55.0     55     55  0.000000      2

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
employee.pivot_table(index=['Department'],values=['Name','Salary'],aggfunc={'Name':'count','Salary':sum})
# Out:
#             Name  Salary
# Department
# HR             3     135
# IT             4     195
# Sales          2     110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
employee.pivot_table(index=['Department','Title'], values=['Years','Salary'], aggfunc={'Years':sum,'Salary':np.mean})
# Out:
#                       Salary  Years
# Department Title
# HR         VP           70.0      8
#            analyst      32.5      6
# IT         VP           70.0      8
#            analyst      32.5      3
#            associate    60.0      7
# Sales      associate    55.0      5

# %% [markdown]
# ### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table.
#
# Hint: Write a custom function.

# %%
#Use a pivot to find the max of each department
max_sal_pivot = employee.pivot_table(index=['Department'],values=['Salary'],aggfunc=['max']).reset_index()
max_sal_pivot
# Add new column on employee table
# Out:
#   Department    max
#              Salary
# 0         HR     70
# 1         IT     70
# 2      Sales     55

# %%
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %%
low_salary = employee.loc[[0,1,2,3,5,7],:]

# %%
low_salary.pivot_table(index=['Department'], values=['Salary'], aggfunc=['mean'])
# Out:
#                  mean
#                Salary
# Department
# HR          32.500000
# IT          41.666667
# Sales       55.000000
